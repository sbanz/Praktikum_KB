# %% [markdown]
# * Reihan Al Sya'Ban
# * 2109106051
# * A2 2021
# * KECERDASAN BUATAN
# * POSTTEST 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Basketball_Players_Stats.csv")

df.head(10)
# Out:
#   League       Season           Stage            Player Team  GP     MIN  FGM  \
# 0    NBA  1999 - 2000  Regular_Season  Shaquille O'Neal  LAL  79  3163.0  956
# 1    NBA  1999 - 2000  Regular_Season      Vince Carter  TOR  82  3126.0  788
# 2    NBA  1999 - 2000  Regular_Season       Karl Malone  UTA  82  2947.0  752
# 3    NBA  1999 - 2000  Regular_Season     Allen Iverson  PHI  70  2853.0  729
# 4    NBA  1999 - 2000  Regular_Season       Gary Payton  SEA  82  3425.0  747
# 5    NBA  1999 - 2000  Regular_Season  Jerry Stackhouse  DET  82  3148.0  619
# 6    NBA  1999 - 2000  Regular_Season        Grant Hill  DET  74  2776.0  696
# 7    NBA  1999 - 2000  Regular_Season     Kevin Garnett  MIN  81  3243.0  759
# 8    NBA  1999 - 2000  Regular_Season    Michael Finley  DAL  82  3464.0  748
# 9    NBA  1999 - 2000  Regular_Season      Chris Webber  SAC  75  2880.0  748
#
#     FGA  3PM  ...    birth_date  height  height_cm  weight  weight_kg  \
# ...

# %%
from numpy import size


season= df.dropna(subset=['Season']).sort_values(by=['Season'])['Season'].unique()

globalrank = df.groupby(['Season'])['GP'].sum()

plt.figure(figsize = (30,15))
plt.plot(season, globalrank, linestyle='--', marker='o', color='red')
plt.grid()
plt.title('Total Permainan Para Pemain Per Season')
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Penjualan (juta)', fontsize=12)
plt.fill_between(season, globalrank, color='lightgreen')


plt.show()

# %% [markdown]
# ### JUMLAH GRAFIK MENUNJUKKAN BERAPA BANYAK TOTAL GAME YANG DIMAINKAN SETIAP PEMAIN DALAM SATU MUSIM

# %%
Stages = df.dropna(subset=['Stage']).sort_values(by=['Stage'])['Stage'].unique()

total = df.groupby(['Stage'])['GP'].count()

patches, texts, pcts = plt.pie(total, labels=Stages, autopct='%.1f%%', wedgeprops={'linewidth': 3.0, 'edgecolor': 'white'},
       textprops={'size': 'x-large'})


plt.title('Total Pemain Basker Berdasarkan Stage')
plt.setp(pcts, color='white', fontweight='bold')
plt.show()

# %% [markdown]
# ### GRAFIK MENUNJUKKAN BERAPA PERSEN TOTAL PERMAINAN BERDASARKAN STAGE DARI SELURUH DATA

# %%
sns.set_style("ticks")
plt.figure(figsize = (25,9))
sns.countplot(data = df, x = "Season", hue = "Stage", palette = "rocket")
plt.title('Perbandingan panggung bermain')
# Out:
# Text(0.5, 1.0, 'Perbandingan panggung bermain')

# %% [markdown]
# ### GRAFIK MENUNJUKKAN BERAPA BANYAK STAGE YANG DIMAINKAN SETIAP PEMAIN DALAM SATU MUSIM
